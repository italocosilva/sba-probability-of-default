# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import PowerTransformer, KBinsDiscretizer, OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

from sklearn.metrics import roc_curve, RocCurveDisplay, roc_auc_score

# %%
# creates a custom data parser before load data (uses SAS timestamp)
custom_date_parser = lambda x: pd.to_datetime(pd.to_numeric(x), origin='1960-01-01', unit='D')

# load the data into a dataframe
df = pd.read_csv('./data/SBAcase.11.13.17.csv', 
                 parse_dates=['ApprovalDate', 'DisbursementDate', 'ChgOffDate'], 
                 date_parser=custom_date_parser)

# drop variables from EDA analysis
df = df.drop(['Selected', 'daysterm', 'xx', 'ApprovalFY', 'NAICS', 'MIS_Status', 'ChgOffPrinGr', 'ChgOffDate',
             'State', 'BalanceGross', 'Name', 'Zip', 'City', 'Bank', 'LoanNr_ChkDgt'], axis=1)

# %%
# adjusting 'NewExist' var and drop 'New' (duplicated info)
NewExist = {1: "Existing Business", 2: "New Business", 0: np.nan}

df.replace({"NewExist": NewExist}, inplace=True)
df.drop(['New'], axis=1, inplace=True)

# %%
# create a column 'Franchise' and drop FranchiseCode
df['Franchise'] = df['FranchiseCode'].apply(lambda x: 'No franchise' if x in [0, 1] else 'Franchise')
df.drop(['FranchiseCode'], axis=1, inplace=True)

# %%
# adjusting 'UrbanRural' var
UrbanRural = {1: "Urban", 2: "Rural", 0: np.nan}

df.replace({"UrbanRural": UrbanRural}, inplace=True)

# %%
# categorical columns
cat_cols = df.select_dtypes('object').columns

# %%
# as macroeconomy changes overtime, it's usually a cycle, using dates to predict default can be dangerous
# so I'll drop dates from the dateset (although I'll keep Recession flag)
df.drop(['ApprovalDate', 'DisbursementDate'], axis=1, inplace=True)

# %% [markdown]
# ## 02. Train-Test-Split

# %%
# splitting
y = df['Default']
X = df.drop(['Default'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# creating the transfomers to treat categorical and numerical data
box_cox = PowerTransformer('box-cox', standardize=False)
discretizer = KBinsDiscretizer(encode='ordinal')
one_hot = OneHotEncoder(drop='first', sparse=False, handle_unknown='ignore')

# %%
# selecting columns to each transformer
cols_box_cox = ['DisbursementGross', 'GrAppv', 'SBA_Appv']
cols_discretizer = ['CreateJob', 'RetainedJob', 'NoEmp']
cols_one_hot = X.select_dtypes('object').columns.to_list()
cols_remainder = [col for col in X.columns if col not in cols_box_cox + cols_discretizer + cols_one_hot]

# %%
# create the compose transformer
ct = ColumnTransformer([
    ('box_cox', box_cox, cols_box_cox),
    ('discretizer', discretizer, cols_discretizer),
    ('one_hot', one_hot, cols_one_hot)
], remainder='passthrough')

# %% [markdown]
# ## 03. Pipeline

# %% [markdown]
# ### 03.a Logistic Regression

# %%
# first try using logistic regression
std_scaler = StandardScaler()
lr = LogisticRegression()

# %%
# creating the pipeline
pipeline_log = Pipeline([
    ('column_transformer', ct),
    ('scaler', std_scaler),
    ('clf', lr)
])

# %%
# setting params to test and creating grid search
params = {'clf__penalty': [None, 'l1', 'l2', 'elasticnet'],
          'clf__C': range(0, 20, 1),
          'clf__solver': ['liblinear', 'lbfgs', 'saga', 'sag']}
cv_log = GridSearchCV(pipeline_log, params, scoring='roc_auc')

# %%
# fitting model and predicting
cv_log.fit(X_train, y_train)
y_pred = cv_log.predict_proba(X_test)[:, 1]
# Out:
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:230: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:230: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 1 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:230: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:230: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 1 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# ...

# %%
# plotting ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
display = RocCurveDisplay(fpr=fpr, tpr=tpr)
display.plot();

# %%
# AUC score - train
roc_auc_score(y_train, cv_log.predict_proba(X_train)[:, 1])
# Out:
# 0.9012272738857339

# %%
# AUC score - test
roc_auc_score(y_test, cv_log.predict_proba(X_test)[:, 1])
# Out:
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:170: UserWarning: Found unknown categories in columns [0, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 0.8994669262504056

# %%
# show best params
cv_log.best_params_
# Out:
# {'clf__C': 3, 'clf__penalty': 'l1', 'clf__solver': 'liblinear'}

# %% [markdown]
# ### 03.b LGBM

# %%
# first try using LightGBM
std_scaler = StandardScaler()
lgbm = LGBMClassifier()

# %%
# creating the pipeline
pipeline_lgbm = Pipeline([
    ('column_transformer', ct),
    ('scaler', std_scaler),
    ('clf', lgbm)
])

# %%
# setting params to test and creating grid search
params = {'clf__boosting_type': ['gbdt', 'dart', 'goss', 'rf'],
         'clf__max_depth': range(3, 13, 1),
         'clf__num_leaves': [2 ** x for x in range(3, 13, 1)]}
cv_lgbm = GridSearchCV(pipeline_lgbm, params, scoring='roc_auc')

# %%
# fitting model and predicting
cv_lgbm.fit(X_train, y_train)
y_pred = cv_lgbm.predict_proba(X_test)[:, 1]
# Out:
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:230: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:230: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 1 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:230: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# ...

# %%
# plotting ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
display = RocCurveDisplay(fpr=fpr, tpr=tpr)
display.plot();

# %%
# AUC score - train
roc_auc_score(y_train, cv_lgbm.predict_proba(X_train)[:, 1])
# Out:
# 0.998739594121504

# %%
# AUC score - test
roc_auc_score(y_test, cv_lgbm.predict_proba(X_test)[:, 1])
# Out:
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:170: UserWarning: Found unknown categories in columns [0, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# 0.9777963194734158

# %%
# show best params
cv_lgbm.best_params_
# Out:
# {'clf__boosting_type': 'dart', 'clf__max_depth': 6, 'clf__num_leaves': 64}

# %%
# fitting pipeline with final params
std_scaler = StandardScaler()
lgbm = LGBMClassifier(boosting_type='dart', max_depth=6, num_leaves=64)

pipeline_lgbm = Pipeline([
    ('column_transformer', ct),
    ('scaler', std_scaler),
    ('clf', lgbm)
])

# %%
# replotting ROC curve
pipeline_lgbm.fit(X_train, y_train)
y_pred = pipeline_lgbm.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
display = RocCurveDisplay(fpr=fpr, tpr=tpr)
display.plot();
# Out:
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:230: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 0 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py:230: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 1 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:170: UserWarning: Found unknown categories in columns [0, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
# calculating gini index - test
gini = 2 * (roc_auc_score(y_test, y_pred) - 0.5)
gini
# Out:
# 0.9555926389468317

# %%
# calculating gini index - train
gini = 2 * (roc_auc_score(y_train, pipeline_lgbm.predict_proba(X_train)[:, 1]) - 0.5)
gini
# Out:
# 0.9974791882430081

# %%
# picking columns out from one hot encoder
cols_out_one_hot = list(pipeline_lgbm.named_steps['column_transformer'].transformers_[2][1].get_feature_names_out())

# %%
# naming all columns from column transformer order
cols = cols_box_cox + cols_discretizer + cols_out_one_hot + cols_remainder

# %%
# creating a Series with feature importance and names
feat_imp = pd.Series(pipeline_lgbm.steps[2][1].feature_importances_, index=cols)

# %%
# plotting feature importance ordered
plt.figure(figsize=(15,10))
sns.barplot(feat_imp.sort_values(ascending=False).values, feat_imp.sort_values(ascending=False).index);
# Out:
# C:\Users\Italo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# printing ROC curves of the 2 models
fpr, tpr, thresholds = roc_curve(y_test, cv_log.predict_proba(X_test)[:, 1])
ax = sns.lineplot(x=fpr, y=tpr)
fpr, tpr, thresholds = roc_curve(y_test, cv_lgbm.predict_proba(X_test)[:, 1])
ax = sns.lineplot(x=fpr, y=tpr)
ax.set(xlabel='False Positive Rate', ylabel='True Positive Rate')
plt.legend(labels=['Logistic', 'LGBM'])
plt.show;
# Out:
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:170: UserWarning: Found unknown categories in columns [0, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\Italo\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:170: UserWarning: Found unknown categories in columns [0, 3] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
